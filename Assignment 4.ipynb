# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
#Reading CSV file
data=pd.read_csv('/content/dat2.csv',encoding="ISO-8859-1")
print(data.to_string())
# Out:
#                   country  Total_Cases     Population        Date
# 0                      USA  34,022,657    332,759,663   27-May-21
# 1                    India  27,729,247  1,392,271,886   27-May-21
# 2                   Brazil  16,392,657    213,926,682   27-May-21
# 3                   France   5,646,897     65,404,386   27-May-21
# 4                   Turkey   5,228,322     85,159,401   27-May-21
# 5                   Russia   5,053,748    145,991,189   27-May-21
# 6                       UK   4,477,705     68,208,871   27-May-21
# 7                    Italy   4,209,707     60,381,191  27/05/2021
# 8                Argentina   3,702,422     45,570,832  27/05/2021
# 9                  Germany   3,680,159     84,026,628  27/05/2021
# 10                   Spain   3,668,658     46,771,195   27-May-21
# 11                Colombia   3,342,567     51,373,140   27-May-21
# 12                    Iran   2,886,111     84,964,116   27-May-21
# ...

# %%
#Finding duplicate entries the Duplicate entries
print((data.duplicated()).to_string())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
#Droping the Duplicate Data
data.drop_duplicates(inplace=True)
print(data.to_string())
# Out:
#                   country  Total_Cases     Population        Date
# 0                      USA  34,022,657    332,759,663   27-May-21
# 1                    India  27,729,247  1,392,271,886   27-May-21
# 2                   Brazil  16,392,657    213,926,682   27-May-21
# 3                   France   5,646,897     65,404,386   27-May-21
# 4                   Turkey   5,228,322     85,159,401   27-May-21
# 5                   Russia   5,053,748    145,991,189   27-May-21
# 6                       UK   4,477,705     68,208,871   27-May-21
# 7                    Italy   4,209,707     60,381,191  27/05/2021
# 8                Argentina   3,702,422     45,570,832  27/05/2021
# 9                  Germany   3,680,159     84,026,628  27/05/2021
# 10                   Spain   3,668,658     46,771,195   27-May-21
# 11                Colombia   3,342,567     51,373,140   27-May-21
# 12                    Iran   2,886,111     84,964,116   27-May-21
# ...

# %%
#removing the rows having NaN values
data.dropna(inplace=True)
print(data.to_string())
# Out:
#                   country  Total_Cases     Population        Date
# 0                      USA  34,022,657    332,759,663   27-May-21
# 1                    India  27,729,247  1,392,271,886   27-May-21
# 2                   Brazil  16,392,657    213,926,682   27-May-21
# 3                   France   5,646,897     65,404,386   27-May-21
# 4                   Turkey   5,228,322     85,159,401   27-May-21
# 5                   Russia   5,053,748    145,991,189   27-May-21
# 6                       UK   4,477,705     68,208,871   27-May-21
# 7                    Italy   4,209,707     60,381,191  27/05/2021
# 8                Argentina   3,702,422     45,570,832  27/05/2021
# 9                  Germany   3,680,159     84,026,628  27/05/2021
# 10                   Spain   3,668,658     46,771,195   27-May-21
# 11                Colombia   3,342,567     51,373,140   27-May-21
# 12                    Iran   2,886,111     84,964,116   27-May-21
# ...

# %%
data.shape
# Out:
# (110, 4)

# %%
print(data.head(5))  #printing first 5 rows
print(data.tail(5))  #printing last 5 rows
# Out:
#   country  Total_Cases     Population       Date
# 0      USA  34,022,657    332,759,663  27-May-21
# 1    India  27,729,247  1,392,271,886  27-May-21
# 2   Brazil  16,392,657    213,926,682  27-May-21
# 3   France   5,646,897     65,404,386  27-May-21
# 4   Turkey   5,228,322     85,159,401  27-May-21
#              country  Total_Cases  Population        Date
# 108  Marshall Islands           4      59,551  27/05/2021
# 109             Samoa           3     199,607  27/05/2021
# 110      Saint Helena           2       6,093  27/05/2021
# 111              Iran   2,886,111  84,964,116  27/05/2021
# 113        Micronesia           1           0  27/05/2021

# %%
#Setting same format for Date column
data['Date']=pd.to_datetime(data['Date'])
print(data.to_string())
# Out:
#                   country  Total_Cases     Population       Date
# 0                      USA  34,022,657    332,759,663 2021-05-27
# 1                    India  27,729,247  1,392,271,886 2021-05-27
# 2                   Brazil  16,392,657    213,926,682 2021-05-27
# 3                   France   5,646,897     65,404,386 2021-05-27
# 4                   Turkey   5,228,322     85,159,401 2021-05-27
# 5                   Russia   5,053,748    145,991,189 2021-05-27
# 6                       UK   4,477,705     68,208,871 2021-05-27
# 7                    Italy   4,209,707     60,381,191 2021-05-27
# 8                Argentina   3,702,422     45,570,832 2021-05-27
# 9                  Germany   3,680,159     84,026,628 2021-05-27
# 10                   Spain   3,668,658     46,771,195 2021-05-27
# 11                Colombia   3,342,567     51,373,140 2021-05-27
# 12                    Iran   2,886,111     84,964,116 2021-05-27
# ...

# %%
data.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#        country  Total_Cases   Population                 Date
# count       110         110          110                  110
# unique      107         105          107                    1
# top        Iran     273,866  117,525,912  2021-05-27 00:00:00
# freq          2           2            2                  110
# first       NaN         NaN          NaN  2021-05-27 00:00:00
# last        NaN         NaN          NaN  2021-05-27 00:00:00

# %%
#checking whether data is cleaned or not
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 0 to 113
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      110 non-null    object
#  1   Total_Cases  110 non-null    object
#  2   Population   110 non-null    object
#  3   Date         110 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 4.3+ KB

# %% [markdown]
# Visualizing Data

# %%
cn = data.loc['country ']
t = data.loc['Total_Cases']
p = data.loc['Population']

# %%
data.plot()
plt.show()

# %% [markdown]
# ![dfgffdgfd.png](data:image/png;base64,...)
